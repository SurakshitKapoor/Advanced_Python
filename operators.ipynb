# %% [markdown]
# # operators in python

# %% [markdown]
# ### 1. arithmetic operators

# %%
# 1. addition
print(10 + 6)
# Out:
# 16

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
# -, *, /, //, %, **

# %%
a = 45.6
b = 56.2
# ans = a-b
# print(ans)
# print(type(ans))

print(a-b)
print(type(a-b))
# Out:
# -10.600000000000001
# <class 'float'>

# %%
# multiplication
x = 11.4
y = 3
print(x * y)
print(type(x * y))
# Out:
# 34.2
# <class 'float'>

# %%
# float division: /
x = 12
y = 7
print(x / y)
print(type(x / y))
# Out:
# 1.7142857142857142
# <class 'float'>

# %%
# floor division: //
x = 12
y = 7
print(x // y)
print(type(x // y))
# Out:
# 1
# <class 'int'>

# %%
# exponential or power operator
x = 5
y = 2
print( x ** y )
print(type(x**y))
# Out:
# 25
# <class 'int'>

# %%
# modulo operator: returns the remainder
x = 12
y = 3
print(x % y)

print()

x = 11
y = 3
print(x % y)

print()

x = 12.3
y = 2
print(x % y)

print()

x = 45.5 
y = 3
print(x % y)
# Out:
# 0
#
# 2
#
# 0.3000000000000007
#
# 0.5

# %% [markdown]
# ### 2. Comparison Operators

# %%
# > , <, == , !=, <=, >=

# %%
# > : greater than
x = 12
y = 2
x > y
# Out:
# True

# %%
print(10 > 4)
print(5 > 10)
# Out:
# True
# False

# %%
# this is about python
x = 12
y = 2
x < y
# Out:
# False

# %%
print(45 < 10)
print(10 < 20)
# Out:
# False
# True

# %%
# == : is equal to 
x == y
# Out:
# False

# %%
print(8 == 8)
print(10 == 2)
print("@hey" == "@Hey")
print("@hey".lower() == "@Hey".lower())
# Out:
# True
# False
# False
# True

# %% [raw]
# # != : not equal to
# x != y

# %%
print(10 != 10)
# Out:
# False

# %%
print(12 != 2)
# Out:
# True

# %%
# <= : less than equal to
# checks whether the left value either less than or, equal to right side value
x <= 12
# Out:
# True

# %%
print(12 <= 2)
print(10 <= 10)
print(-15 <= 15)
# Out:
# False
# True
# True

# %%
# >=: greater than equal to
# checks whether the left value is either greater than or equal to right value

# %%
print(12 >= 2)
print(15 >= 15)
print(-2 >= 10)
# Out:
# True
# True
# False

# %%
y >= 2
# Out:
# True

# %%
y >= 2
# Out:
# True

# %% [markdown]
# ### 3. logical operators

# %%
# and, or, not

# %%
# used to check the combined result of two or more comparisons operations

# %%
# and - 
# returns True only when all the conditions are True

# storin result of 1st conition
ans_1 = 10 <= 2

# storing result of 2nd conition
ans_2 = 12 == 12

print(ans_1 and ans_2)
# Out:
# False

# %%
print( 15==20 and 2==2)
# Out:
# False

# %%
print( 4 <= 5 and 10 >= 4)
# Out:
# True

# %%
print( 4 <= 5 and 5 <= 2)
# Out:
# False

# %%
print( 100 <= 45 and 45 >= 5 and 67 <= 50)
# Out:
# False

# %%
print( "hey"=="hey" and 1 <= 5 and 15 < 50)
# Out:
# True

# %%
print("hey"=="hey")
print(1 <= 5)
print(15 < 50)
# Out:
# True
# True
# True

# %%
# 2). or
# returns True when "any" of the combined condition is True

# %%
print( 10 <= 10 or "hey"=="hello")
# Out:
# True

# %%
print("a"=="b" or 5 <= 10)
# Out:
# True

# %%
print(45 <= 10 or 5 < 2)
# Out:
# False

# %%
# not : 
# # it toggles / swap / reverse the boolean result

# %%
print( not(10==10) )
# Out:
# False

# %%
print( not("a"=="b" or 5 <= 10) )
# Out:
# False

# %%
print( not ( not("a"=="b") or not(5 <= 10) )  )
# Out:
# False

# %%
print( not("a"=="b") and 5 <= 10 )
# Out:
# True

# %%
print( not(10==2) or 89==98 )
# Out:
# True

# %% [markdown]
# ### 4. assignment operators

# %%
# = , +=, -=, *=, /=, //=, %=

# %%
# these just assigns the values to the variable

# %%
var = 10

# same variable is updated with it older value
var = var + 20

print(var)
# Out:
# 30

# %%
# assignment-addition
var = 10
# var = var + 20
var += 20
print(var)
# Out:
# 30

# %%
# assinment-subtr
print("var is : ", var)
# var = var-5
var -= 5
print(var)
# Out:
# var is :  30
# 25

# %%
# multiplication-assignment
print("var is: ", var)
var *= 10
print(var)
# Out:
# var is:  25
# 250

# %%
print("var is : ", var)
var /= 4
print(var)
# Out:
# var is :  250
# 62.5

# %%
print("var is : ", var)
# var = var ** 2
var **= 2
print(var)
# Out:
# var is :  62.5
# 3906.25

# %%
print("var is : ", var)
var %= 4
print(var)
# Out:
# var is :  3906.25
# 2.25

# %% [markdown]
# ### 5. bitwise operators

# %%
# &, |, ^, <<, >>, ~

# %%
# biwtise and: &

# %%
print( 10 & 2 )
# Out:
# 2

# %%
print( 12 & 4 )
# Out:
# 4

# %%
print( 100 & 12 )
# Out:
# 4

# %%
print( 10 | 4 )
# Out:
# 14

# %%
print( 8 & 4 )
# Out:
# 0

# %%
# 8:  0000000000001000
# 4:  0000000000000100
# 12: 0000000000001100
# 0: 0000000000000

# 1111
# 1010
# &
# 1010

# |
# 1111

# %%
print( 2 | 4 )
# Out:
# 6

# %%
# 2: 0000000000000010
# 4: 0000000000000100
# 6: 0000000000000110

# %%
# biwtise not
~12
# Out:
# -13

# %%
# 1011101
# 0100010

# %%
print( "a"=="a" or "b"=="b" )
# Out:
# True

# %%
# left shift
print( 10 << 2 )
# 0000000000001010
# 0000000000101000
# Out:
# 40

# %%
print( 45 >> 2 )
# 101101
# >>2
# 001011
# 11
# Out:
# 11

# %%
# biwtise not
print( ~10 )
# Out:
# -11

# %%
# bitwise xor
print( 10 ^ 2 )
# 8: 1010101
# 2: 1001111

# xor : sameinputs -> 0
# differnt inpust -> 1
# Out:
# 8

# %%
var = 12

# %%
var + 12
# Out:
# 24

# %%
var - 2
# Out:
# 10

# %%
x + 23
# Out:
# 35

# %%
x = 26

# %% [markdown]
# ### 6. membership operator

# %%
ans = 45 in [12, 90, 78, 45, 15]
print(ans)
# Out:
# True

# %%
ans = 10 in [12, 90, 78, 45, 15]
print(ans)
# Out:
# False

# %%
ans = "aman" not in [12, 90, 78, 45, 15]
print(ans)
# Out:
# True

# %% [markdown]
# ### 7. identity operator

# %%
a = 10
b = 10

ans = a is b
print(ans)
# Out:
# True

# %% [markdown]
# both a and b are pointing to a same memory location (object), so that's why the both locations are same and result is true.

# %%
a = 10
b = 12

ans = a is b
print(ans)
# Out:
# False
