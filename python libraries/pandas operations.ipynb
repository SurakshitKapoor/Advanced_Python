# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\DELL\\Downloads\\TelecomCustomerChurn.csv")

# %%
data.head()
# Out:
#    customerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1            No             DSL            Yes  ...              Yes
# 2            No             DSL            Yes  ...               No
# 3            No             DSL            Yes  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.ndim
# Out:
# 2

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
df = data.copy()
df.shape
# Out:
# (7043, 21)

# %%
df.reset_index()
# Out:
#       index  customerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 0         0  7590-VHVEG  Female              0     Yes         No       1
# 1         1  5575-GNVDE    Male              0      No         No      34
# 2         2  3668-QPYBK    Male              0      No         No       2
# 3         3  7795-CFOCW    Male              0      No         No      45
# 4         4  9237-HQITU  Female              0      No         No       2
# ...     ...         ...     ...            ...     ...        ...     ...
# 7038   7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039   7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040   7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041   7041  8361-LTMKD    Male              1     Yes         No       4
# 7042   7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
(df.groupby('Gender')['Tenure'].mean().reset_index().rename(columns={"Tenure":"Avg Tenure"}).round(2)['Avg Tenure'] > 32.25).reset_index()
# Out:
#    index  Avg Tenure
# 0      0       False
# 1      1        True

# %%
df.groupby(['Gender', 'InternetService']).size()['Female', 'DSL']
# Out:
# np.int64(1188)

# %%
df.groupby(['Gender', 'InternetService']).size()
# Out:
# Gender  InternetService
# Female  DSL                1188
#         Fiber optic        1553
#         No                  747
# Male    DSL                1233
#         Fiber optic        1543
#         No                  779
# dtype: int64

# %%
df.groupby(['Gender', 'InternetService']).size().index.tolist()
# Out:
# [('Female', 'DSL'),
#  ('Female', 'Fiber optic'),
#  ('Female', 'No'),
#  ('Male', 'DSL'),
#  ('Male', 'Fiber optic'),
#  ('Male', 'No')]

# %%
df.groupby(['Gender', 'InternetService']).size().index.get_level_values("Gender").unique()
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
df.groupby(['Gender', 'InternetService']).size().reset_index()
# Out:
#    Gender InternetService     0
# 0  Female             DSL  1188
# 1  Female     Fiber optic  1553
# 2  Female              No   747
# 3    Male             DSL  1233
# 4    Male     Fiber optic  1543
# 5    Male              No   779

# %%
df.groupby(['Gender', 'InternetService']).agg(
    Total_Tenure=('Tenure', 'sum')
)
# Out:
#                         Total_Tenure
# Gender InternetService
# Female DSL                     38993
#        Fiber optic             50301
#        No                      23175
# Male   DSL                     40468
#        Fiber optic             51613
#        No                      23440

# %%
df.groupby(['Gender', 'InternetService']).agg(
    Total_Tenure=('Tenure', 'sum')
).columns
# Out:
# Index(['Total_Tenure'], dtype='object')

# %%
df['TotalCharges'].dtype
# Out:
# dtype('O')

# %%
df.groupby(['Gender', 'InternetService']).agg(
    Total_Tenure=('Tenure', 'sum')
).loc[('Female', 'DSL'), 'Total_Tenure']
# Out:
# np.int64(38993)

# %%
df.groupby(['Gender', 'InternetService']).agg(
    Total_Tenure=('Tenure', 'sum')
).index.get_level_values("InternetService")
# Out:
# Index(['DSL', 'Fiber optic', 'No', 'DSL', 'Fiber optic', 'No'], dtype='object', name='InternetService')

# %%
df.groupby(['Gender', 'InternetService']).agg(
    Total_Tenure=('Tenure', 'sum')
).loc['Female','DSL']
# Out:
# Total_Tenure    38993
# Name: (Female, DSL), dtype: int64

# %%
ans = df.groupby(['Gender', 'InternetService']).agg(
    Total_Tenure=('Tenure', 'sum')
).reset_index()

# %%
ans[ans['Gender']=='Female']
# Out:
#    Gender InternetService  Total_Tenure
# 0  Female             DSL         38993
# 1  Female     Fiber optic         50301
# 2  Female              No         23175

# %%
ans
# Out:
#    Gender InternetService  Total_Tenure
# 0  Female             DSL         38993
# 1  Female     Fiber optic         50301
# 2  Female              No         23175
# 3    Male             DSL         40468
# 4    Male     Fiber optic         51613
# 5    Male              No         23440

# %%
ans.loc[1:4, 'Total_Tenure']
# Out:
# 1    50301
# 2    23175
# 3    40468
# 4    51613
# Name: Total_Tenure, dtype: int64

# %%
ans.loc[[1,3,5], 'Total_Tenure']
# Out:
# 1    50301
# 3    40468
# 5    23440
# Name: Total_Tenure, dtype: int64

# %%
ans.loc[ans['Gender']=='Female', 'Total_Tenure']
# Out:
# 0    38993
# 1    50301
# 2    23175
# Name: Total_Tenure, dtype: int64

# %%
ans.columns
# Out:
# Index(['Gender', 'InternetService', 'Total_Tenure'], dtype='object')

# %%
ans.set_index("InternetService").loc['DSL', 'Total_Tenure']
# Out:
# InternetService
# DSL    38993
# DSL    40468
# Name: Total_Tenure, dtype: int64

# %%
ans.iloc[1:3, 0:2]
# Out:
#    Gender InternetService
# 1  Female     Fiber optic
# 2  Female              No

# %%
ans.columns
# Out:
# Index(['Gender', 'InternetService', 'Total_Tenure'], dtype='object')

# %%
ans[['Gender',  'Total_Tenure', 'InternetService']]
# Out:
#    Gender  Total_Tenure InternetService
# 0  Female         38993             DSL
# 1  Female         50301     Fiber optic
# 2  Female         23175              No
# 3    Male         40468             DSL
# 4    Male         51613     Fiber optic
# 5    Male         23440              No
